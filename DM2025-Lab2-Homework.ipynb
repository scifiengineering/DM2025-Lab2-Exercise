# %% [markdown]
# ### **Student Information**
# Name: Sifiso Lucolo Dhlamini
#
# Student ID: 114065424
#
# GitHub ID: scifiengineering
#
# Kaggle name: Sifiso Lucolo Dhlamini
#
# Kaggle private scoreboard snapshot:
#
# ![Score Report](pics/lastSubmission.jpg)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](./pics/lab2_deadlines.png)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
# ## 1. Model Development (10 pts Required)
#
# ### 1.1 Preprocessing Steps
#
# I loaded the dataset from the provided **JSON and CSV files** (`final_posts.json`, `data_identification.csv`, `emotion.csv`). I performed text cleaning which involved:
# *   Removing user handles (e.g., @user).
# *   Removing URLs.
# *   Removing non-alphanumeric characters.
# *   Converting text to lowercase.
# *   **Lemmatization**: Converting words to their base form using NLTK's WordNetLemmatizer.
# *   Removing English stopwords.
#
# ### 1.2 Feature Engineering Steps
#
# I transitioned from simple TF-IDF to **Sequence Tokenization** for my Deep Learning models.
# *   **Tokenization**: I converted words into integer indices using a vocabulary size of 10,000.
# *   **Padding**: I padded all sequences to a fixed length of 100 to ensure uniform input for the neural network.
# *   **Label Encoding**: I one-hot encoded the target emotion labels.
#
# ### 1.3 Explanation of Your Model
#
# I implemented a **Bidirectional LSTM (Long Short-Term Memory)** neural network as my primary custom architecture.
# *   **Embedding Layer**: Maps word indices to dense vectors of dimension **50** (reduced from 100 to fight overfitting).
# *   **Bidirectional LSTM**: Captures context from both past and future words in the sequence. I used **32 units**.
# *   **GlobalMaxPool1D**: Reduces the sequence output to a single vector.
# *   **Dense & Dropout**: A fully connected layer with ReLU activation, **L2 Regularization**, and **Dropout (0.6)** to prevent overfitting.
# *   **Output Layer**: A Softmax layer to predict the probability of each of the 4 emotions.
#
# ---
#
# ## 2. Bonus Section (5 pts Optional)
#
# ### 2.1 Mention Different Things You Tried
#
# I experimented with a **Multinomial Naive Bayes** classifier as a baseline using TF-IDF features.
#
# I then moved to Transformer-based models:
# *   **DistilBERT**: I fine-tuned `distilbert-base-uncased` with a classification head.
# *   **RoBERTa**: I experimented with `roberta-base` to see if its robust pre-training offered advantages.
#
# ### 2.2 Mention Insights You Gained (Analysis)
#
# *   **Overfitting in Bi-LSTM**: The LSTM model showed severe overfitting (High Train Acc, Low Val Acc). I addressed this by reducing model complexity and increasing regularization (Dropout/L2).
# *   **Model Capacity vs. Data Size**: I hypothesized RoBERTa would outperform DistilBERT. However, I found that RoBERTa's larger capacity led it to overfit the small dataset faster than the lighter DistilBERT. This taught me that larger models aren't always better for small datasets without careful tuning.
#
# ### 2.3 Iterative Improvements & Advanced Strategies
#
# To achieve my final high score, I implemented the following advanced strategies:
#
# 1.  **Optimizer Tuning (AdamW)**: I switched to **AdamW** (Weight Decay) for the Transformers. This prevented the weights from growing too large, acting as a strong regularizer.
# 2.  **RoBERTa Tuning**: I **lowered the learning rate to 1e-5** for RoBERTa. This stabilized the training and helped mitigate the overfitting issue I identified in 2.2.
# 3.  **Ensemble Learning**: I implemented a **Soft Voting Ensemble**. I combined the probability predictions of my fine-tuned DistilBERT and RoBERTa models. By averaging their outputs, I smoothed out individual model errors, leading to better generalization and my best leaderboard score.
#
#
#
# ### Late Observation
#
# **Observed class imbalance:**
# After preprocessing, the training split contains **38,312 samples** with a heavily skewed emotion distribution:
# - **Joy** accounts for **49.7%** of examples
# - **Disgust** covers only **2.5%**
#
# This imbalance risks models learning a **joy-biased predictor**, inflating aggregate accuracy while underperforming on minority emotions.
#
# **If discovered earlier, we would have:**
# 1. Computed and recorded **class counts** during preprocessing.
# 2. Applied **class-aware training** (e.g., class weights or focal loss).
# 3. Performed **targeted data augmentation** (back‑translation/paraphrasing) for underrepresented classes, or mild **undersampling of joy**.
#
#
# ---

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
import pandas as pd
import numpy as np
import re
import os
import json
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # Remove user handles
    text = re.sub(r'@\w+', '', text)
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove non-alphanumeric characters (except spaces)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Lowercase
    text = text.lower()
    # Tokenize (simple split)
    words = text.split()
    # Remove stopwords and Lemmatize
    cleaned_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(cleaned_words)

# --- DATA LOADING LOGIC ---
DATA_DIR = 'data'
# External path for large JSON dataset
EXTERNAL_DATA_DIR = '/Users/scifithedev/Documents/Taiwan Masters/NTHU/2025 Fall/Data Mining - Concepts,Techniques, andApplications/Lab-2/dm-lab-2-private-competition'
FINAL_POSTS_PATH = os.path.join(EXTERNAL_DATA_DIR, 'final_posts.json')

# Fallback to local data dir if external not found
if not os.path.exists(FINAL_POSTS_PATH):
    FINAL_POSTS_PATH = os.path.join(DATA_DIR, 'final_posts.json')

ID_FILE_PATH = os.path.join(DATA_DIR, 'data_identification.csv')
EMOTION_FILE_PATH = os.path.join(DATA_DIR, 'emotion.csv')

def load_competition_data():
    print("Loading competition data...")
    
    # Check for existence
    if not os.path.exists(ID_FILE_PATH): raise FileNotFoundError(f"Missing {ID_FILE_PATH}")
    if not os.path.exists(EMOTION_FILE_PATH): raise FileNotFoundError(f"Missing {EMOTION_FILE_PATH}")
    if not os.path.exists(FINAL_POSTS_PATH): raise FileNotFoundError(f"Missing {FINAL_POSTS_PATH}")

    # 1. Load IDs and Splits
    id_df = pd.read_csv(ID_FILE_PATH)
    print(f"Loaded {len(id_df)} IDs from data_identification.csv")
    
    # 2. Load Labels (Training set only)
    emotion_df = pd.read_csv(EMOTION_FILE_PATH)
    print(f"Loaded {len(emotion_df)} labels from emotion.csv")
    
    # 3. Load Text (Parsing nested JSON)
    print(f"Loading text from {FINAL_POSTS_PATH}...")
    with open(FINAL_POSTS_PATH, 'r') as f:
        posts_data = json.load(f)
    
    # Parse the nested structure: root -> _source -> post -> [post_id, text]
    parsed_data = []
    for entry in posts_data:
        try:
            post_info = entry['root']['_source']['post']
            parsed_data.append({
                'id': post_info['post_id'],
                'text': post_info['text']
            })
        except KeyError:
            continue # Skip malformed entries
            
    text_df = pd.DataFrame(parsed_data)
    print(f"Loaded {len(text_df)} texts from final_posts.json")
    
    # --- MERGING ---
    # Ensure 'id' is string in all dfs
    id_df['id'] = id_df['id'].astype(str)
    emotion_df['id'] = emotion_df['id'].astype(str)
    text_df['id'] = text_df['id'].astype(str)

    # Merge text with IDs
    full_df = pd.merge(id_df, text_df, on='id', how='left')
    
    # Split into Train and Test based on 'split' column
    train_ids = full_df[full_df['split'] == 'train']
    test_ids = full_df[full_df['split'] == 'test']
    
    # Merge Labels into Train
    train_df = pd.merge(train_ids, emotion_df, on='id', how='left')
    
    # Test set for competition (no labels)
    competition_test_df = test_ids.copy()
    
    return train_df, competition_test_df

# Main Execution
try:
    train_df, competition_test_df = load_competition_data()
    
    # Split Train into Train/Validation
    train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['emotion'])
    
    print(f"Data prepared successfully.")
    print(f"Training Set: {len(train_df)} samples")
    print(f"Validation Set: {len(val_df)} samples")
    print(f"Competition Test Set: {len(competition_test_df)} samples (blind)")

    # Apply cleaning
    print("Cleaning training data...")
    train_df['cleaned_text'] = train_df['text'].apply(clean_text)
    print("Cleaning validation data...")
    val_df['cleaned_text'] = val_df['text'].apply(clean_text)
    print("Cleaning competition test data...")
    competition_test_df['cleaned_text'] = competition_test_df['text'].apply(clean_text)
    
    print("Preprocessing complete.")
    print(train_df[['text', 'cleaned_text']].head())

except Exception as e:
    print(f"Error: {e}")
    print("Please ensure all data files are present.")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/scifithedev/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/scifithedev/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/scifithedev/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Loading competition data...
# Loaded 64171 IDs from data_identification.csv
# Loaded 47890 labels from emotion.csv
# Loading text from /Users/scifithedev/Documents/Taiwan Masters/NTHU/2025 Fall/Data Mining - Concepts,Techniques, andApplications/Lab-2/dm-lab-2-private-competition/final_posts.json...
# Loaded 64171 texts from final_posts.json
# Data prepared successfully.
# Training Set: 38312 samples
# Validation Set: 9578 samples
# Competition Test Set: 16281 samples (blind)
# Cleaning training data...
# ...

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from transformers import DistilBertTokenizer
import numpy as np

# Parameters
MAX_WORDS = 10000
MAX_LEN_LSTM = 100
MAX_LEN_BERT = 128
MODEL_NAME = 'distilbert-base-uncased'

# Alias val_df to test_df for compatibility
if 'val_df' in locals():
    test_df = val_df
    print("Using 'val_df' as 'test_df' for validation.")

# --- PREPARATION FOR LSTM ---
print("\n--- Preparing Data for LSTM ---")
# Tokenization
tokenizer_lstm = Tokenizer(num_words=MAX_WORDS, oov_token='<OOV>')
tokenizer_lstm.fit_on_texts(train_df['cleaned_text'])

# Convert text to sequences
X_train_seq = tokenizer_lstm.texts_to_sequences(train_df['cleaned_text'])
X_test_seq = tokenizer_lstm.texts_to_sequences(test_df['cleaned_text'])

# Padding
X_train_pad = pad_sequences(X_train_seq, maxlen=MAX_LEN_LSTM, padding='post', truncating='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=MAX_LEN_LSTM, padding='post', truncating='post')

print("LSTM Data Ready.")
print("X_train_pad shape:", X_train_pad.shape)

# --- PREPARATION FOR BERT ---
print("\n--- Preparing Data for BERT ---")
print(f"Loading {MODEL_NAME} tokenizer...")
tokenizer_bert = DistilBertTokenizer.from_pretrained(MODEL_NAME)

def bert_encode(data, maximum_length):
    input_ids = []
    attention_masks = []

    for text in data:
        encoded = tokenizer_bert.encode_plus(
            text,
            add_special_tokens=True,
            max_length=maximum_length,
            padding='max_length',
            return_attention_mask=True,
            truncation=True
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])
        
    return np.array(input_ids), np.array(attention_masks)

print("Tokenizing data for BERT (using raw text)...")
# Use raw 'text' for BERT, not 'cleaned_text'
X_train_ids, X_train_masks = bert_encode(train_df['text'], MAX_LEN_BERT)
X_test_ids, X_test_masks = bert_encode(test_df['text'], MAX_LEN_BERT)

print("BERT Data Ready.")
print("X_train_ids shape:", X_train_ids.shape)

# --- LABELS ---
# Encode labels (Shared)
label_encoder = LabelEncoder()
y_train_le = label_encoder.fit_transform(train_df['emotion'])
y_test_le = label_encoder.transform(test_df['emotion'])

# Convert to categorical
y_train_cat = to_categorical(y_train_le)
y_test_cat = to_categorical(y_test_le)

print("\nLabels encoded.")
print("Classes:", label_encoder.classes_)
# Out:
# Using 'val_df' as 'test_df' for validation.
#
# --- Preparing Data for LSTM ---
# LSTM Data Ready.
# X_train_pad shape: (38312, 100)
#
# --- Preparing Data for BERT ---
# Loading distilbert-base-uncased tokenizer...
# LSTM Data Ready.
# X_train_pad shape: (38312, 100)
#
# --- Preparing Data for BERT ---
# Loading distilbert-base-uncased tokenizer...
# Tokenizing data for BERT (using raw text)...
# Tokenizing data for BERT (using raw text)...
# BERT Data Ready.
# X_train_ids shape: (38312, 128)
#
# Labels encoded.
# Classes: ['anger' 'disgust' 'fear' 'joy' 'sadness' 'surprise']
# BERT Data Ready.
# X_train_ids shape: (38312, 128)
#
# Labels encoded.
# Classes: ['anger' 'disgust' 'fear' 'joy' 'sadness' 'surprise']

# %%
# Show class distributions
import matplotlib.pyplot as plt
import seaborn as sns

def show_emotion_counts(df, label="train"):
    counts = df['emotion'].value_counts(dropna=False).sort_index()
    pct = counts / counts.sum()
    print(f"\n=== {label.upper()} set ===")
    print(counts)
    print("\nRelative distribution:")
    print((pct*100).round(2).astype(str) + "%")
    plt.figure(figsize=(6,4))
    sns.barplot(x=counts.index, y=counts.values, palette='muted')
    plt.title(f"Emotion counts ({label})")
    plt.ylabel("Count")
    plt.xlabel("Emotion")
    plt.tight_layout()
    plt.show()

# If train/val/test dataframes exist:
if 'train_df' in globals():
    show_emotion_counts(train_df, label='train')
if 'val_df' in globals():
    show_emotion_counts(val_df, label='validation')
if 'test_df' in globals():
    show_emotion_counts(test_df, label='test')
# Out:
# === TRAIN set ===
# emotion
# anger        8555
# disgust       946
# fear         1607
# joy         19038
# sadness      3141
# surprise     5025
# Name: count, dtype: int64
#
# Relative distribution:
# emotion
# anger       22.33%
# disgust      2.47%
# fear         4.19%
# joy         49.69%
# sadness       8.2%
# surprise    13.12%
# Name: count, dtype: object
# /var/folders/n0/svvdhbh169b0z6vpwn9ykpm00000gn/T/ipykernel_41432/1405884931.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='muted')
# === VALIDATION set ===
# emotion
# anger       2139
# disgust      237
# fear         402
# joy         4759
# sadness      785
# surprise    1256
# Name: count, dtype: int64
#
# Relative distribution:
# emotion
# anger       22.33%
# disgust      2.47%
# fear          4.2%
# ...

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout, GlobalMaxPool1D
from tensorflow.keras.callbacks import EarlyStopping as EarlyStopping_Keras
from tensorflow.keras import regularizers
from transformers import TFDistilBertForSequenceClassification
from sklearn.utils import class_weight
from sklearn.metrics import f1_score
import tensorflow as tf
import tf_keras
from tf_keras.callbacks import EarlyStopping as EarlyStopping_TF_Keras
from tf_keras.losses import CategoricalCrossentropy as CategoricalCrossentropy_TF_Keras
import numpy as np

# Optimizer Imports
# 1. For LSTM (Keras 3 / tensorflow.keras): Use standard Adam. Legacy is not supported in Keras 3.
from tensorflow.keras.optimizers import Adam as Adam_Keras
print("Using standard Adam optimizer for LSTM (Keras 3)")

# 2. For DistilBERT (Keras 2 / tf_keras): Use AdamW (Weight Decay) as recommended for Transformers.
# Try to import AdamW from tf_keras, falling back to Adam if not found.
try:
    from tf_keras.optimizers import AdamW as AdamW_TF_Keras
    print("Using tf_keras.optimizers.AdamW for DistilBERT")
    optimizer_bert_class = AdamW_TF_Keras
    optimizer_kwargs = {'weight_decay': 0.01}
except (ImportError, AttributeError):
    print("AdamW not found in tf_keras.optimizers. Falling back to Legacy Adam.")
    try:
        from tf_keras.optimizers.legacy import Adam as Adam_Legacy
        optimizer_bert_class = Adam_Legacy
        optimizer_kwargs = {}
    except (ImportError, AttributeError):
        from tf_keras.optimizers import Adam as Adam_TF_Keras
        optimizer_bert_class = Adam_TF_Keras
        optimizer_kwargs = {}

# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_le),
    y=y_train_le
)
class_weights_dict = dict(enumerate(class_weights))
print("Class Weights:", class_weights_dict)
num_classes = len(label_encoder.classes_)

# --- MODEL 1: Bi-LSTM (Improved Regularization) ---
print("\n" + "="*30)
print("TRAINING MODEL 1: Bi-LSTM (Regularized)")
print("="*30)

# Reduced complexity to fight overfitting
model_lstm = Sequential([
    Embedding(input_dim=MAX_WORDS, output_dim=50), # Reduced from 100
    Bidirectional(LSTM(32, return_sequences=True)), # Reduced from 64
    GlobalMaxPool1D(),
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)), # Added L2 Reg
    Dropout(0.6), # High dropout
    Dense(num_classes, activation='softmax')
])

model_lstm.compile(optimizer=Adam_Keras(learning_rate=0.001),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# Set patience to 15 to ensure it trains for all epochs as requested, but keeps best weights
early_stopping_lstm = EarlyStopping_Keras(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

history_lstm = model_lstm.fit(
    X_train_pad, y_train_cat,
    epochs=15,
    batch_size=32,
    validation_data=(X_test_pad, y_test_cat),
    class_weight=class_weights_dict,
    callbacks=[early_stopping_lstm],
    verbose=1
)

# Evaluate LSTM
y_pred_probs_lstm = model_lstm.predict(X_test_pad)
y_pred_classes_lstm = np.argmax(y_pred_probs_lstm, axis=1)
f1_lstm = f1_score(np.argmax(y_test_cat, axis=1), y_pred_classes_lstm, average='macro')
print(f"Bi-LSTM Test Mean F1 Score: {f1_lstm:.4f}")


# --- MODEL 2: DistilBERT (Using tf_keras for compatibility) ---
print("\n" + "="*30)
print("TRAINING MODEL 2: DistilBERT")
print("="*30)

try:
    model_bert = TFDistilBertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=num_classes)
except (TypeError, ValueError) as e:
    print(f"Error loading with defaults: {e}. Retrying with use_safetensors=False...")
    model_bert = TFDistilBertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=num_classes, use_safetensors=False)

# Use the selected optimizer class for BERT
optimizer_bert = optimizer_bert_class(learning_rate=2e-5, epsilon=1e-08, **optimizer_kwargs)
loss_bert = CategoricalCrossentropy_TF_Keras(from_logits=True)

model_bert.compile(optimizer=optimizer_bert, loss=loss_bert, metrics=['accuracy'])

early_stopping_bert = EarlyStopping_TF_Keras(monitor='val_loss', patience=2, restore_best_weights=True, verbose=1)

history_bert = model_bert.fit(
    [X_train_ids, X_train_masks],
    y_train_cat,
    epochs=3,
    batch_size=16,
    validation_data=([X_test_ids, X_test_masks], y_test_cat),
    class_weight=class_weights_dict,
    callbacks=[early_stopping_bert],
    verbose=1
)

# Evaluate BERT
y_pred_logits_bert = model_bert.predict([X_test_ids, X_test_masks]).logits
y_pred_classes_bert = np.argmax(y_pred_logits_bert, axis=1)
f1_bert = f1_score(np.argmax(y_test_cat, axis=1), y_pred_classes_bert, average='macro')
print(f"DistilBERT Test Mean F1 Score: {f1_bert:.4f}")

# Comparison
print("\n" + "="*30)
print("MODEL COMPARISON")
print("="*30)
print(f"Bi-LSTM F1: {f1_lstm:.4f}")
print(f"DistilBERT F1: {f1_bert:.4f}")

if f1_bert > f1_lstm:
    print("Best Model: DistilBERT")
    best_model = model_bert
    best_model_type = 'bert'
else:
    print("Best Model: Bi-LSTM")
    best_model = model_lstm
    best_model_type = 'lstm'
# Out:
# Using standard Adam optimizer for LSTM (Keras 3)
# Using tf_keras.optimizers.AdamW for DistilBERT
# Class Weights: {0: 0.7463861289694136, 1: 6.749823819591262, 2: 3.973449491806679, 3: 0.335399376685226, 4: 2.0328982277406347, 5: 1.2707131011608623}
#
# ...
# TRAINING MODEL 1: Bi-LSTM (Regularized)
# ...
# Epoch 1/15
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.2820 - loss: 1.8013 - val_accuracy: 0.4612 - val_loss: 1.6723
# Epoch 2/15
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.2820 - loss: 1.8013 - val_accuracy: 0.4612 - val_loss: 1.6723
# Epoch 2/15
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 83s 69ms/step - accuracy: 0.3440 - loss: 1.7161 - val_accuracy: 0.3888 - val_loss: 1.5144
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 83s 69ms/step - accuracy: 0.3440 - loss: 1.7161 - val_accuracy: 0.3888 - val_loss: 1.5144
# Epoch 3/15
# Epoch 3/15
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 82s 68ms/step - accuracy: 0.3504 - loss: 1.6605 - val_accuracy: 0.3879 - val_loss: 1.4931
# Epoch 4/15
# ...

# %%
import matplotlib.pyplot as plt

def plot_history(history, model_name):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()

    plt.show()

# Plot Bi-LSTM
if 'history_lstm' in locals():
    print("Plotting Bi-LSTM History:")
    plot_history(history_lstm, "Bi-LSTM")
else:
    print("Bi-LSTM history not found.")

# Plot DistilBERT
if 'history_bert' in locals():
    print("Plotting DistilBERT History:")
    plot_history(history_bert, "DistilBERT")
else:
    print("DistilBERT history not found.")
# Out:
# Plotting Bi-LSTM History:
# Plotting DistilBERT History:

# %% [markdown]
# ## 4. Bonus Experiments (Optional)
# Trying a different model: Multinomial Naive Bayes.
# *Note: I use TF-IDF vectorization here as it is more suitable for Naive Bayes than the sequence padding used for the LSTM.*

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report

# Re-create TF-IDF features for Naive Bayes (it works better with TF-IDF than sequences)
print("Vectorizing data with TF-IDF for Naive Bayes...")
tfidf_nb = TfidfVectorizer(max_features=5000)
X_train_nb = tfidf_nb.fit_transform(train_df['cleaned_text'])
X_test_nb = tfidf_nb.transform(test_df['cleaned_text'])

# Use original labels
y_train_nb = train_df['emotion']
y_test_nb = test_df['emotion']

# Initialize model
nb_model = MultinomialNB()

# Train model
nb_model.fit(X_train_nb, y_train_nb)

# Predict
y_pred_nb = nb_model.predict(X_test_nb)

# Evaluate
accuracy_nb = accuracy_score(y_test_nb, y_pred_nb)
print(f"Naive Bayes Accuracy: {accuracy_nb:.4f}")
print("\nClassification Report (Naive Bayes):\n")
print(classification_report(y_test_nb, y_pred_nb))
# Out:
# Vectorizing data with TF-IDF for Naive Bayes...
# Naive Bayes Accuracy: 0.5630
#
# Classification Report (Naive Bayes):
#
#               precision    recall  f1-score   support
#
#        anger       0.60      0.34      0.44      2139
#      disgust       0.00      0.00      0.00       237
#         fear       0.68      0.04      0.08       402
#          joy       0.56      0.96      0.71      4759
#      sadness       0.50      0.02      0.03       785
#     surprise       0.59      0.04      0.08      1256
#
#     accuracy                           0.56      9578
#    macro avg       0.49      0.23      0.22      9578
# weighted avg       0.56      0.56      0.46      9578
#
# Naive Bayes Accuracy: 0.5630
#
# Classification Report (Naive Bayes):
#
#               precision    recall  f1-score   support
#
#        anger       0.60      0.34      0.44      2139
#      disgust       0.00      0.00      0.00       237
#         fear       0.68      0.04      0.08       402
# ...

# %%
# 4.2 RoBERTa Model (Advanced Experiment)
# ---------------------------------------------------------
# RoBERTa (Robustly optimized BERT approach) often outperforms DistilBERT.
# We use the same training pipeline but with the RoBERTa tokenizer and model.

from transformers import TFRobertaForSequenceClassification, RobertaTokenizer
import tensorflow as tf
import numpy as np
from sklearn.metrics import f1_score

# Check for tf_keras (required for Transformers with TF 2.16+)
try:
    import tf_keras
    HAS_TF_KERAS = True
    print("tf_keras library is available. Using it for Model, Optimizer, and Callbacks.")
except ImportError:
    HAS_TF_KERAS = False
    print("tf_keras library NOT found. Using standard tensorflow.keras.")

MODEL_NAME_ROBERTA = 'roberta-base'

# --- PREPARATION FOR ROBERTA ---
print(f"Loading {MODEL_NAME_ROBERTA} tokenizer...")
tokenizer_roberta = RobertaTokenizer.from_pretrained(MODEL_NAME_ROBERTA)

def roberta_encode(data, maximum_length):
    input_ids = []
    attention_masks = []

    for text in data:
        encoded = tokenizer_roberta.encode_plus(
            text,
            add_special_tokens=True,
            max_length=maximum_length,
            padding='max_length',
            return_attention_mask=True,
            truncation=True
        )
        input_ids.append(encoded['input_ids'])
        attention_masks.append(encoded['attention_mask'])
        
    return np.array(input_ids), np.array(attention_masks)

print("Tokenizing data for RoBERTa...")
# Re-using MAX_LEN_BERT from previous cells (128)
X_train_ids_rob, X_train_masks_rob = roberta_encode(train_df['text'], MAX_LEN_BERT)
X_test_ids_rob, X_test_masks_rob = roberta_encode(test_df['text'], MAX_LEN_BERT)

print("RoBERTa Data Ready.")

# Initialize RoBERTa model
try:
    model_roberta = TFRobertaForSequenceClassification.from_pretrained(MODEL_NAME_ROBERTA, num_labels=num_classes)
except (TypeError, ValueError) as e:
    print(f"Error loading with defaults: {e}. Retrying with use_safetensors=False...")
    model_roberta = TFRobertaForSequenceClassification.from_pretrained(MODEL_NAME_ROBERTA, num_labels=num_classes, use_safetensors=False)

# Optimizer & Callbacks Configuration
# LOWER LEARNING RATE for RoBERTa (1e-5) to prevent overfitting
if HAS_TF_KERAS:
    # Use tf_keras components to match the model
    try:
        from tf_keras.optimizers import AdamW
        print("Using tf_keras.optimizers.AdamW (Weight Decay)")
        optimizer_roberta = AdamW(learning_rate=1e-5, weight_decay=0.01, epsilon=1e-08)
    except (ImportError, AttributeError):
        try:
            from tf_keras.optimizers.legacy import Adam
            print("Using tf_keras.optimizers.legacy.Adam (M1/M2 Acceleration)")
        except (ImportError, AttributeError):
            from tf_keras.optimizers import Adam
            print("Using tf_keras.optimizers.Adam")
        optimizer_roberta = Adam(learning_rate=1e-5, epsilon=1e-08)
    
    loss_roberta = tf_keras.losses.CategoricalCrossentropy(from_logits=True)
    
    # IMPORTANT: Must use tf_keras callback with tf_keras model
    early_stopping_roberta = tf_keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=2, restore_best_weights=True
    )
else:
    # Fallback to standard Keras
    try:
        from tensorflow.keras.optimizers import AdamW
        print("Using tensorflow.keras.optimizers.AdamW")
        optimizer_roberta = AdamW(learning_rate=1e-5, weight_decay=0.01, epsilon=1e-08)
    except (ImportError, AttributeError):
        try:
            from tensorflow.keras.optimizers.legacy import Adam
            print("Using tensorflow.keras.optimizers.legacy.Adam")
        except (ImportError, AttributeError):
            from tensorflow.keras.optimizers import Adam
            print("Using tensorflow.keras.optimizers.Adam")
        optimizer_roberta = Adam(learning_rate=1e-5, epsilon=1e-08)
        
    loss_roberta = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    
    early_stopping_roberta = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=2, restore_best_weights=True
    )

model_roberta.compile(optimizer=optimizer_roberta, loss=loss_roberta, metrics=['accuracy'])

print("\nTraining RoBERTa Model...")
history_roberta = model_roberta.fit(
    [X_train_ids_rob, X_train_masks_rob],
    y_train_cat,
    validation_data=([X_test_ids_rob, X_test_masks_rob], y_test_cat),
    epochs=4, # Increased epochs slightly since LR is lower
    batch_size=16,
    callbacks=[early_stopping_roberta],
    class_weight=class_weights_dict
)

# Evaluation
print("\nEvaluating RoBERTa Model...")
loss_rob, acc_rob = model_roberta.evaluate([X_test_ids_rob, X_test_masks_rob], y_test_cat)
print(f"RoBERTa Accuracy: {acc_rob:.4f}")

# F1 Score Calculation
y_pred_logits_rob = model_roberta.predict([X_test_ids_rob, X_test_masks_rob]).logits
y_pred_classes_rob = np.argmax(y_pred_logits_rob, axis=1)

f1_rob = f1_score(y_test_le, y_pred_classes_rob, average='macro')
print(f"RoBERTa Macro F1 Score: {f1_rob:.4f}")

# --- ENSEMBLE EVALUATION ---
print("\n" + "="*30)
print("ENSEMBLE EVALUATION (DistilBERT + RoBERTa)")
print("="*30)

# Get probabilities (Softmax)
probs_bert = tf.nn.softmax(y_pred_logits_bert).numpy()
probs_rob = tf.nn.softmax(y_pred_logits_rob).numpy()

# Average Probabilities
probs_ensemble = (probs_bert + probs_rob) / 2
pred_ensemble = np.argmax(probs_ensemble, axis=1)

f1_ensemble = f1_score(y_test_le, pred_ensemble, average='macro')
print(f"Ensemble Macro F1 Score: {f1_ensemble:.4f}")

# Compare and Select Best
scores = {'bert': f1_bert, 'roberta': f1_rob, 'ensemble': f1_ensemble}
best_type = max(scores, key=scores.get)

print(f"\nWINNER: {best_type.upper()} with F1: {scores[best_type]:.4f}")

best_model_type = best_type
if best_type == 'bert':
    best_model = model_bert
elif best_type == 'roberta':
    best_model = model_roberta
else:
    # For ensemble, we need both. We'll handle this in the submission cell.
    best_model = None 
    print("Ensemble selected. Both models will be used for submission.")
# Out:
# tf_keras library is available. Using it for Model, Optimizer, and Callbacks.
# Loading roberta-base tokenizer...
# Tokenizing data for RoBERTa...
# Tokenizing data for RoBERTa...
# RoBERTa Data Ready.
# RoBERTa Data Ready.
# Error loading with defaults: 'builtins.safe_open' object is not iterable. Retrying with use_safetensors=False...
# Error loading with defaults: 'builtins.safe_open' object is not iterable. Retrying with use_safetensors=False...
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# Some layers of TFRobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
# Plot RoBERTa History
if 'history_roberta' in locals():
    print("Plotting RoBERTa History:")
    plot_history(history_roberta, "RoBERTa")
else:
    print("RoBERTa history not found. Ensure the model has been trained.")
# Out:
# Plotting RoBERTa History:

# %% [markdown]
# ### 4.2 RoBERTa Model Experiment
#
# **Hypothesis**: RoBERTa, being a more robustly optimized version of BERT (trained on more data, longer sequences, and dynamically masking patterns), should theoretically capture more subtle emotional nuances than the distilled version (DistilBERT).
#
# **Experiment Setup**:
# - **Model**: `roberta-base`
# - **Tokenizer**: `RobertaTokenizer`
# - **Parameters**: Same learning rate (2e-5) and batch size (16) as DistilBERT for fair comparison.
# - **Optimization for M1/M2 Macs**: To address the slow training performance of the standard `tf.keras.optimizers.Adam` on Apple Silicon devices, we explicitly utilize `tf.keras.optimizers.legacy.Adam`. This enables the use of the Metal Performance Shaders (MPS) graph, significantly reducing training time from hours to minutes.
#
# **Results**:
# - We compare the Weighted F1 Score of RoBERTa against the baseline DistilBERT model.
# - The `best_model` variable is automatically updated to the winner of this comparison for the final submission generation.
#
# **Final Outcome (Local Validation)**:
# - **Ensemble (DistilBERT + RoBERTa)**: **F1 Score = 0.5087** (Winner)
# - **DistilBERT (Standalone)**: **F1 Score = 0.4983**
# - **Bi-LSTM**: **F1 Score = 0.2847**
#
# **Kaggle Public Leaderboard Results**:
# - **DistilBERT (Initial Run)**: **0.6448** (Best Result)
# - **Ensemble**: **0.6344**
# - **DistilBERT (Retrained)**: **0.6301**
#
# **Analysis**:
# While the Ensemble model performed best in local validation, the simpler **DistilBERT** model achieved the highest score on the public leaderboard (0.6448). This discrepancy suggests that the more complex Ensemble model (and potentially the RoBERTa component) may be **overfitting** to the local training/validation data, whereas the lighter DistilBERT model generalizes better to the unseen test set. Adding complexity or training longer appears to yield diminishing returns or regression in this specific scenario.

# %% [markdown]
# ## 5. Generate Submission File
# Code to generate the CSV file for Kaggle submission.

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf

# Generate Submission using the BEST model

try:
    if 'competition_test_df' not in locals():
        raise ValueError("competition_test_df not found. Ensure Data Loading cell has been executed.")
    
    # Check if best_model is set (unless it's ensemble)
    if best_model_type != 'ensemble' and 'best_model' not in locals():
        raise ValueError("best_model not found. Ensure Model Implementation cell has been executed.")

    print(f"Generating predictions using {best_model_type.upper()} strategy...")
    print(f"Test samples: {len(competition_test_df)}")
    
    if best_model_type == 'ensemble':
        print("--- Ensemble Prediction (DistilBERT + RoBERTa) ---")
        
        # 1. DistilBERT Predictions
        print("1/2: Generating DistilBERT logits...")
        X_kaggle_ids_bert, X_kaggle_masks_bert = bert_encode(competition_test_df['text'], MAX_LEN_BERT)
        logits_bert = model_bert.predict([X_kaggle_ids_bert, X_kaggle_masks_bert], batch_size=32, verbose=1).logits
        probs_bert = tf.nn.softmax(logits_bert).numpy()
        
        # 2. RoBERTa Predictions
        print("2/2: Generating RoBERTa logits...")
        if 'roberta_encode' not in locals():
             raise ValueError("roberta_encode function not found. Please run the RoBERTa training cell first.")
        X_kaggle_ids_rob, X_kaggle_masks_rob = roberta_encode(competition_test_df['text'], MAX_LEN_BERT)
        logits_rob = model_roberta.predict([X_kaggle_ids_rob, X_kaggle_masks_rob], batch_size=32, verbose=1).logits
        probs_rob = tf.nn.softmax(logits_rob).numpy()
        
        # 3. Average Probabilities
        print("Averaging probabilities...")
        probs_ensemble = (probs_bert + probs_rob) / 2
        kaggle_predictions_idx = np.argmax(probs_ensemble, axis=1)

    elif best_model_type == 'bert':
        # Tokenize for BERT
        print("Tokenizing for BERT...")
        X_kaggle_ids, X_kaggle_masks = bert_encode(competition_test_df['text'], MAX_LEN_BERT)
        
        # Predict
        print("Predicting...")
        kaggle_predictions_logits = best_model.predict([X_kaggle_ids, X_kaggle_masks], batch_size=32, verbose=1).logits
        kaggle_predictions_idx = np.argmax(kaggle_predictions_logits, axis=1)
        
    elif best_model_type == 'roberta':
        # Tokenize for RoBERTa
        print("Tokenizing for RoBERTa...")
        if 'roberta_encode' not in locals():
             raise ValueError("roberta_encode function not found. Please run the RoBERTa training cell first.")
             
        X_kaggle_ids, X_kaggle_masks = roberta_encode(competition_test_df['text'], MAX_LEN_BERT)
        
        # Predict
        print("Predicting...")
        kaggle_predictions_logits = best_model.predict([X_kaggle_ids, X_kaggle_masks], batch_size=32, verbose=1).logits
        kaggle_predictions_idx = np.argmax(kaggle_predictions_logits, axis=1)

    else: # lstm
        # Tokenize for LSTM
        print("Tokenizing for LSTM...")
        X_kaggle_seq = tokenizer_lstm.texts_to_sequences(competition_test_df['cleaned_text'])
        X_kaggle_pad = pad_sequences(X_kaggle_seq, maxlen=MAX_LEN_LSTM, padding='post', truncating='post')
        
        # Predict
        print("Predicting...")
        kaggle_predictions_prob = best_model.predict(X_kaggle_pad, batch_size=32, verbose=1)
        kaggle_predictions_idx = np.argmax(kaggle_predictions_prob, axis=1)
    
    # Decode labels
    kaggle_predictions_label = label_encoder.inverse_transform(kaggle_predictions_idx)
    
    # Create submission DataFrame
    submission_df = pd.DataFrame({
        'id': competition_test_df['id'],
        'emotion': kaggle_predictions_label
    })
    
    # Save submission with auto-numbering to prevent overwriting
    base_filename = 'submission'
    extension = '.csv'
    submission_filename = base_filename + extension
    
    if os.path.exists(submission_filename):
        counter = 1
        while os.path.exists(f"{base_filename}_{counter}{extension}"):
            counter += 1
        submission_filename = f"{base_filename}_{counter}{extension}"
    
    submission_df.to_csv(submission_filename, index=False)
    print(f"Submission file '{submission_filename}' created successfully.")
    print(submission_df.head())
    
except Exception as e:
    print(f"Error generating submission: {e}")
# Out:
# Generating predictions using ENSEMBLE strategy...
# Test samples: 16281
# --- Ensemble Prediction (DistilBERT + RoBERTa) ---
# 1/2: Generating DistilBERT logits...
#
# Test samples: 16281
# --- Ensemble Prediction (DistilBERT + RoBERTa) ---
# 1/2: Generating DistilBERT logits...
# ...
# 509/509 [==============================] - 896s 2s/step
# 2/2: Generating RoBERTa logits...
# 2/2: Generating RoBERTa logits...
# ...
# 509/509 [==============================] - 1786s 4s/step
# Averaging probabilities...
# Submission file 'submission_2.csv' created successfully.
#          id  emotion
# 0  0x61fc95     fear
# 4  0xaba820     fear
# 5  0x66e44d      joy
# 6  0xc03cf5      joy
# 8  0x02f65a  sadness
# Averaging probabilities...
# Submission file 'submission_2.csv' created successfully.
#          id  emotion
# 0  0x61fc95     fear
# 4  0xaba820     fear
# 5  0x66e44d      joy
# 6  0xc03cf5      joy
# 8  0x02f65a  sadness

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf

# Force generation of DistilBERT submission
print("Generating DistilBERT-only submission...")

if 'model_bert' not in locals():
    raise ValueError("model_bert not found. Please ensure the DistilBERT training cell was executed.")

# Tokenize
print("Tokenizing for DistilBERT...")
X_kaggle_ids, X_kaggle_masks = bert_encode(competition_test_df['text'], MAX_LEN_BERT)

# Predict
print("Predicting with DistilBERT...")
logits_bert = model_bert.predict([X_kaggle_ids, X_kaggle_masks], batch_size=32, verbose=1).logits
probs_bert = tf.nn.softmax(logits_bert).numpy()
kaggle_predictions_idx = np.argmax(probs_bert, axis=1)

# Decode labels
kaggle_predictions_label = label_encoder.inverse_transform(kaggle_predictions_idx)

# Create submission DataFrame
submission_df = pd.DataFrame({
    'id': competition_test_df['id'],
    'emotion': kaggle_predictions_label
})

# Save
filename = 'submission_distilbert_only.csv'
submission_df.to_csv(filename, index=False)
print(f"Saved DistilBERT-only submission to {filename}")
print(submission_df.head())
# Out:
# Generating DistilBERT-only submission...
# Tokenizing for DistilBERT...
# Predicting with DistilBERT...
# Predicting with DistilBERT...
# ...
# 509/509 [==============================] - 789s 2s/step
# Saved DistilBERT-only submission to submission_distilbert_only.csv
#          id  emotion
# 0  0x61fc95     fear
# 4  0xaba820     fear
# 5  0x66e44d      joy
# 6  0xc03cf5      joy
# 8  0x02f65a  sadness
# Saved DistilBERT-only submission to submission_distilbert_only.csv
#          id  emotion
# 0  0x61fc95     fear
# 4  0xaba820     fear
# 5  0x66e44d      joy
# 6  0xc03cf5      joy
# 8  0x02f65a  sadness
